# %%
import numpy as np

# %%
H = -(np.log2(4/7)*(4/7) + np.log2(3/7)*(3/7) )
Hs = -(np.log2(1/3)*(1/3) + np.log2(2/3)*(2/3))
H-Hs*(3/7)
# Out:
# 0.5916727785823275

# %%
p = [0.5,0.2,0.2,0.1]
-np.sum(p*np.log2(p))
# Out:
# 1.7609640474436812

# %%
# Out:
# 0.1383458330929479
